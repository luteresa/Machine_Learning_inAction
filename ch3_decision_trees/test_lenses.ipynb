# %%
import trees
import treePlotter

# %%
fr=open('lenses.txt')
lenses = [inst.strip().split('\t') for inst in fr.readlines()]
lensesLabels=['age','prescript','astigmatic','tearRate']

# %%
lensesTree = trees.createTree(lenses,lensesLabels)

# %%
treePlotter.createPlot(lensesTree)
# Out:
# plotTree off:(-0.05555555555555555,1.0),parentPt:(0.5, 1.0),cntrPt:(0.5, 1.0)
# plotTree off:(-0.05555555555555555,0.75),parentPt:(0.5, 1.0),cntrPt:(0.4444444444444444, 0.75)
# plotTree off:(-0.05555555555555555,0.5),parentPt:(0.4444444444444444, 0.75),cntrPt:(0.22222222222222224, 0.5)
# plotTree off:(0.05555555555555555,0.25),parentPt:(0.22222222222222224, 0.5),cntrPt:(0.2222222222222222, 0.25)
# plotTree off:(0.3888888888888889,0.5),parentPt:(0.4444444444444444, 0.75),cntrPt:(0.6666666666666667, 0.5)
# plotTree off:(0.3888888888888889,0.25),parentPt:(0.6666666666666667, 0.5),cntrPt:(0.6111111111111112, 0.25)
